# %%
import pandas as pd

df = pd.read_csv('employee_dummy_100.csv')
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-c457aa726054> in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.readcsv('employee_dummy_100.csv')
#       4 df.head(5)
#
# c:\Users\s2608\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     262         return _SparseArray
#     263
# --> 264     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     265
#     266
#
# AttributeError: module 'pandas' has no attribute 'readcsv'
